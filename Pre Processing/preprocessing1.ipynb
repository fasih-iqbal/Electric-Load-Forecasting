# %% [markdown]
# **Reading each file and converting into data frame**

# %%
import pandas as pd

# Initialize an empty list to store the DataFrames
demand_data = []
weather_data = []

# %%
def drop_columns(df, columns):

    return df.drop(columns=columns, errors='ignore')

# %%
def display_data(df):

    # Display column names and datatypes
    print("\nColumn Names:")
    print(df.columns.tolist())

    print("\nData Types:")
    print(df.dtypes)

    print("\nFirst 2 Rows:")
    print(df.head(2))

# %%
def preprocess_json_file(path, city):
    path = path
    
    df = pd.read_json(path)
    
    
    display_data(df)

    df['timestamp'] = pd.to_datetime(df['time'], unit='s')

    df['timestamp'] = pd.to_datetime(df['timestamp'])

    columns_to_drop = [
        'summary',
        'icon',
        'apparentTemperature',
        'dewPoint',
        'windGust',
        'windBearing',
        'cloudCover',
        'uvIndex',
        'visibility',
        'precipType',
        'ozone',
        'precipAccumulation',
        'time'
    ]

    df = drop_columns(df, columns_to_drop)

    df['city'] = city 

    return df

# %% [markdown]
# **1) cleaned_balance_data.csv**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/cleaned_balance_data.csv"

df = pd.read_csv(path)
display_data(df)

columns_to_drop = ['company', 'utc_time']

df = drop_columns(df, columns_to_drop)
df.rename(columns={'local_time': 'timestamp'}, inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'])


# Append to the list
demand_data.append(df)
df
# Out:
# Column Names:
# ['company', 'local_time', 'utc_time', 'demand', 'city']
#
# Data Types:
# company        object
# local_time     object
# utc_time       object
# demand        float64
# city           object
# dtype: object
#
# First 2 Rows:
#   company           local_time             utc_time  demand     city
# 0    AZPS  2018-07-01 01:00:00  2018-07-01 08:00:00  3497.0  phoenix
# 1    AZPS  2018-07-01 02:00:00  2018-07-01 09:00:00  3256.0  phoenix
#                 timestamp  demand     city
# 0     2018-07-01 01:00:00  3497.0  phoenix
# 1     2018-07-01 02:00:00  3256.0  phoenix
# 2     2018-07-01 03:00:00  3065.0  phoenix
# 3     2018-07-01 04:00:00  2929.0  phoenix
# 4     2018-07-01 05:00:00  2833.0  phoenix
# ...                   ...     ...      ...
# 31915 2020-04-25 20:00:00     NaN  seattle
# 31916 2020-04-25 21:00:00     NaN  seattle
# 31917 2020-04-25 22:00:00     NaN  seattle
# 31918 2020-04-25 23:00:00     NaN  seattle
# 31919 2020-04-26 00:00:00     NaN  seattle
#
# ...

# %%
print(df['city'].value_counts())
# Out:
# city
# phoenix    15960
# seattle    15960
# Name: count, dtype: int64

# %% [markdown]
# **2) cleaned_subregion_data.csv**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/cleaned_subregion_data.csv"

df = pd.read_csv(path)
display_data(df)

columns_to_drop = ['company', 'region', 'utc_time']
df = drop_columns(df, columns_to_drop)
df.rename(columns={'local_time': 'timestamp'}, inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Append to the list
demand_data.append(df)
df
# Out:
# Column Names:
# ['company', 'region', 'demand', 'local_time', 'utc_time', 'city']
#
# Data Types:
# company        object
# region         object
# demand        float64
# local_time     object
# utc_time       object
# city           object
# dtype: object
#
# First 2 Rows:
#   company region  demand           local_time             utc_time city
# 0    NYIS   ZONJ  7269.0  2018-07-01 01:00:00  2018-07-01 05:00:00  nyc
# 1    NYIS   ZONJ  6977.0  2018-07-01 02:00:00  2018-07-01 06:00:00  nyc
#          demand           timestamp      city
# 0        7269.0 2018-07-01 01:00:00       nyc
# 1        6977.0 2018-07-01 02:00:00       nyc
# 2        6725.0 2018-07-01 03:00:00       nyc
# 3        6539.0 2018-07-01 04:00:00       nyc
# 4        6415.0 2018-07-01 05:00:00       nyc
# ...         ...                 ...       ...
# 132283  11578.0 2020-05-19 20:00:00  san jose
# 132284  11782.0 2020-05-19 21:00:00  san jose
# 132285  11592.0 2020-05-19 22:00:00  san jose
# ...

# %%
print(df['city'].value_counts())
# Out:
# city
# nyc             16536
# la              16536
# houston         16536
# philadelphia    16536
# san antonio     16536
# san diego       16536
# dallas          16536
# san jose        16536
# Name: count, dtype: int64

# %% [markdown]
# **3) cleaned_texas_data**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/cleaned_texas_data.csv"

df = pd.read_csv(path)
display_data(df)

df = pd.melt(df, id_vars=['date'], var_name='city', value_name='demand')
df.rename(columns={'date': 'timestamp'}, inplace=True)
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Append to the list
demand_data.append(df)
df
# Out:
# Column Names:
# ['date', 'houston', 'san antonio', 'dallas']
#
# Data Types:
# date            object
# houston        float64
# san antonio    float64
# dallas         float64
# dtype: object
#
# First 2 Rows:
#                   date   houston  san antonio    dallas
# 0  2018-01-01 01:00:00  11425.98      9151.19  18584.34
# 1  2018-01-01 02:00:00  11408.42      9144.99  18524.14
#                 timestamp     city    demand
# 0     2018-01-01 01:00:00  houston  11425.98
# 1     2018-01-01 02:00:00  houston  11408.42
# 2     2018-01-01 03:00:00  houston  11405.20
# 3     2018-01-01 04:00:00  houston  11450.56
# 4     2018-01-01 05:00:00  houston  11631.34
# ...                   ...      ...       ...
# 61264 2020-04-30 20:00:00   dallas  13521.17
# 61265 2020-04-30 21:00:00   dallas  13149.45
# 61266 2020-04-30 22:00:00   dallas  12673.02
# 61267 2020-04-30 23:00:00   dallas  11653.34
# 61268 2020-04-30 00:00:00   dallas  10505.68
#
# [61269 rows x 3 columns]

# %%
print(df['city'].value_counts())
# Out:
# city
# houston        20423
# san antonio    20423
# dallas         20423
# Name: count, dtype: int64

# %% [markdown]
# **4) dallas.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/dallas.json"

df = preprocess_json_file(path, 'dallas')

# Append to the list
weather_data.append(df)
df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# **5) houston.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/houston.json"

df = preprocess_json_file(path, 'houston')

# Append to the list
weather_data.append(df)
df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# **6) la.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/la.json"

df = preprocess_json_file(path, 'la')

# Append to the list
weather_data.append(df)

df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# dtype: object
#
# First 2 Rows:
#          time   summary         icon  precipIntensity  precipProbability  \
# ...

# %% [markdown]
# **7) nyc.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/nyc.json"

df = preprocess_json_file(path, 'nyc')

# Append to the list
weather_data.append(df)

df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# **8) philadelphia.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/philadelphia.json"

df = preprocess_json_file(path, 'philadelphia')

# Append to the list
weather_data.append(df)
df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# **9) phoenix**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/phoenix.json"

df = preprocess_json_file(path, 'phoenix')

# Append to the list
weather_data.append(df)

df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# **10) san_antonio**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/san_antonio.json"

df = preprocess_json_file(path, 'san antonio')

# Append to the list
weather_data.append(df)
df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# **11) san_diego**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/san_diego.json"

df = preprocess_json_file(path, 'san diego')

# Append to the list
weather_data.append(df)

df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# dtype: object
#
# First 2 Rows:
#          time   summary    icon  precipIntensity  precipProbability  \
# ...

# %% [markdown]
# **12) san_jose.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/san_jose.json"

df = preprocess_json_file(path, 'san jose')

# Append to the list
weather_data.append(df)

df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'ozone', 'precipType']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# ozone                  float64
# precipType              object
# dtype: object
#
# First 2 Rows:
#          time summary         icon  precipIntensity  precipProbability  \
# ...

# %% [markdown]
# **13) seattle.json**

# %%
path = "C:/University Work/6th Semester/Data Mining Lab/project/dataset/seattle.json"

df = preprocess_json_file(path, 'seattle')

# Append to the list
weather_data.append(df)

df.head()
# Out:
# Column Names:
# ['time', 'summary', 'icon', 'precipIntensity', 'precipProbability', 'temperature', 'apparentTemperature', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 'windBearing', 'cloudCover', 'uvIndex', 'visibility', 'precipType', 'ozone', 'precipAccumulation']
#
# Data Types:
# time                     int64
# summary                 object
# icon                    object
# precipIntensity        float64
# precipProbability      float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# windGust               float64
# windBearing            float64
# cloudCover             float64
# uvIndex                float64
# visibility             float64
# precipType              object
# ozone                  float64
# precipAccumulation     float64
# dtype: object
#
# First 2 Rows:
# ...

# %% [markdown]
# # Merging the demands and weather data

# %%
# Combine all demand and weather data into single DataFrames
all_demand = pd.concat(demand_data, ignore_index=True)
all_weather = pd.concat(weather_data, ignore_index=True)

# Merge the datasets on timestamp and city
data = pd.merge(all_demand, all_weather, on=['timestamp', 'city'], how='inner')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212066 entries, 0 to 212065
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   timestamp          212066 non-null  datetime64[ns]
#  1   demand             186142 non-null  float64
#  2   city               212066 non-null  object
#  3   precipIntensity    211776 non-null  float64
#  4   precipProbability  211776 non-null  float64
#  5   temperature        212053 non-null  float64
#  6   humidity           212053 non-null  float64
#  7   pressure           211997 non-null  float64
#  8   windSpeed          211999 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 14.6+ MB

# %%
data.head()
# Out:
#             timestamp  demand     city  precipIntensity  precipProbability  \
# 0 2018-07-01 07:00:00  2764.0  phoenix              0.0                0.0
# 1 2018-07-01 08:00:00  2895.0  phoenix              0.0                0.0
# 2 2018-07-01 09:00:00  3096.0  phoenix              0.0                0.0
# 3 2018-07-01 10:00:00  3293.0  phoenix              0.0                0.0
# 4 2018-07-01 11:00:00  3552.0  phoenix              0.0                0.0
#
#    temperature  humidity  pressure  windSpeed
# 0        86.82      0.16    1008.9       4.30
# 1        83.37      0.19    1009.3       4.00
# 2        82.22      0.18    1009.5       2.47
# 3        80.34      0.19    1010.1       2.98
# 4        79.34      0.18    1010.4       2.74

# %%
data.to_csv('merged_data.csv')
